# %% [markdown]
# # Cifar-10 이미지 분류 v2
# - 데이터 부풀리기 적용

# %%
import numpy as np
import tensorflow as tf
seed = 2022
np.random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# - 데이터 전처리

# %%
from tensorflow.keras.datasets import cifar10
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 11s 0us/step
# 170508288/170498071 [==============================] - 11s 0us/step

# %%
X_train.shape, X_test.shape, y_train.shape
# Out:
# ((50000, 32, 32, 3), (10000, 32, 32, 3), (50000, 1))

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,2))
for i in range(10):
    plt.subplot(1,10,i+1)
    plt.imshow(X_train[i]), plt.axis('off')
    plt.title(class_names[y_train[i,0]], fontsize=8)

plt.show()

# %%
# X data: 0~1 사이의 실수(float32)로 변환 (정규화)
# 이미지 데이터 0~255 사이의 값 가짐. 0~1 사이의 값에서 최적의 성능을 가짐. 따라서 255로 나눔.
X_train = X_train.astype('float32') / 255.
X_test = X_test.astype(np.float32) / 255.

# %%
# y_data: One-hot encoding
from tensorflow.keras.utils import to_categorical
Y_train = to_categorical(y_train)
Y_test = to_categorical(y_test)

# %% [markdown]
# - 모델 정의/설정/학습/평가

# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import RMSprop

# %%
model = Sequential([
    Conv2D(32, (3,3), padding='same', input_shape=(32,32,3), activation='relu'),
    Conv2D(32, (3,3), activation='relu'),
    MaxPooling2D(),
    Dropout(0.25),
    Conv2D(64, (3,3), padding='same', activation='relu'),
    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(),
    Dropout(0.25),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(10, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  conv2d_1 (Conv2D)           (None, 30, 30, 32)        9248
#
#  max_pooling2d (MaxPooling2D  (None, 15, 15, 32)       0
#  )
#
#  dropout (Dropout)           (None, 15, 15, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 15, 15, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 13, 13, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 6, 6, 64)          0
#
#  flatten (Flatten)           (None, 2304)              0
#
#  dense (Dense)               (None, 512)               1180160
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 1,250,858
# Trainable params: 1,250,858
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer=RMSprop(learning_rate=0.0001, decay=1e-6),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
model_path = 'best-cifar10-v2.h5'
checkpoint = ModelCheckpoint(model_path, save_best_only=True, verbose=1)
early_stop = EarlyStopping(patience=10)

# %% [markdown]
# - 데이터 부풀리기
#     - 데이터가 부족한 경우 도움을 줌

# %%
from sklearn.model_selection import train_test_split
X_train, X_valid, Y_train, Y_valid = train_test_split(
    X_train, Y_train, stratify=Y_train, test_size=0.2, random_state=seed
)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    featurewise_center=False,               # set input mean to 0 over the dataset
    samplewise_center=False,                # set each sample mean to 0
    featurewise_std_normalization=False,    # divide inputs by std of dataset
    samplewise_std_normalization=False,     # divide each input by its std
    zca_whitening=False,                    # apply ZCA whitening
    zca_epsilon=1e-06,                      # epsilon for ZCA whitening
    rotation_range=0,                       # randomly rotate images in the range (deg 0 to 180)
    width_shift_range=0.1,                  # randomly shift images horizontally
    height_shift_range=0.1,                 # randomly shift images vertically
    shear_range=0.,                         # set range for random shear
    zoom_range=0.1,                         # set range for random zoom
    channel_shift_range=0.,                 # set range for random channel shifts
    fill_mode='nearest',                    # set mode for filling points outside the input boundaries
    cval=0.,                                # value used for fill_mode = "constant"
    horizontal_flip=True,                   # randomly flip images
    vertical_flip=False,                    # randomly flip images
    rescale=None,                           # set rescaling factor (applied before any other transformation)
    preprocessing_function=None,            # set function that will be applied on each input
    data_format=None,                       # image data format, either "channels_first" or "channels_last"
    validation_split=0.0                    # fraction of images reserved for validation
)
datagen.fit(X_train)

# %%
hist = model.fit(
    datagen.flow(X_train, Y_train, batch_size=32), 
    validation_data=(X_valid, Y_valid),
    epochs=100, verbose=2,
    callbacks=[checkpoint, early_stop]
)
# Out:
# Epoch 1/100
#
# Epoch 00001: val_loss improved from inf to 1.58554, saving model to best-cifar10-v2.h5
# 1250/1250 - 32s - loss: 1.8813 - accuracy: 0.3056 - val_loss: 1.5855 - val_accuracy: 0.4238 - 32s/epoch - 26ms/step
# Epoch 2/100
#
# Epoch 00002: val_loss improved from 1.58554 to 1.44117, saving model to best-cifar10-v2.h5
# 1250/1250 - 21s - loss: 1.6071 - accuracy: 0.4064 - val_loss: 1.4412 - val_accuracy: 0.4775 - 21s/epoch - 17ms/step
# Epoch 3/100
#
# Epoch 00003: val_loss improved from 1.44117 to 1.36149, saving model to best-cifar10-v2.h5
# 1250/1250 - 21s - loss: 1.5026 - accuracy: 0.4521 - val_loss: 1.3615 - val_accuracy: 0.5157 - 21s/epoch - 17ms/step
# Epoch 4/100
#
# Epoch 00004: val_loss did not improve from 1.36149
# 1250/1250 - 21s - loss: 1.4238 - accuracy: 0.4867 - val_loss: 1.4096 - val_accuracy: 0.5069 - 21s/epoch - 17ms/step
# Epoch 5/100
#
# Epoch 00005: val_loss improved from 1.36149 to 1.22528, saving model to best-cifar10-v2.h5
# 1250/1250 - 21s - loss: 1.3588 - accuracy: 0.5109 - val_loss: 1.2253 - val_accuracy: 0.5605 - 21s/epoch - 17ms/step
# Epoch 6/100
#
# Epoch 00006: val_loss improved from 1.22528 to 1.12611, saving model to best-cifar10-v2.h5
# 1250/1250 - 21s - loss: 1.3024 - accuracy: 0.5348 - val_loss: 1.1261 - val_accuracy: 0.6004 - 21s/epoch - 17ms/step
# Epoch 7/100
#
# Epoch 00007: val_loss improved from 1.12611 to 1.09419, saving model to best-cifar10-v2.h5
# 1250/1250 - 21s - loss: 1.2547 - accuracy: 0.5543 - val_loss: 1.0942 - val_accuracy: 0.6131 - 21s/epoch - 17ms/step
# Epoch 8/100
#
# Epoch 00008: val_loss improved from 1.09419 to 1.05516, saving model to best-cifar10-v2.h5
# 1250/1250 - 21s - loss: 1.2144 - accuracy: 0.5702 - val_loss: 1.0552 - val_accuracy: 0.6290 - 21s/epoch - 16ms/step
# Epoch 9/100
#
# Epoch 00009: val_loss improved from 1.05516 to 1.03376, saving model to best-cifar10-v2.h5
# 1250/1250 - 21s - loss: 1.1766 - accuracy: 0.5839 - val_loss: 1.0338 - val_accuracy: 0.6334 - 21s/epoch - 17ms/step
# Epoch 10/100
#
# Epoch 00010: val_loss did not improve from
ms/step
# Epoch 50/100
#
# Epoch 00050: val_loss did not improve from 0.72279
# 1250/1250 - 21s - loss: 0.8153 - accuracy: 0.7212 - val_loss: 0.7573 - val_accuracy: 0.7494 - 21s/epoch - 17ms/step
# Epoch 51/100
#
# Epoch 00051: val_loss did not improve from 0.72279
# 1250/1250 - 21s - loss: 0.8151 - accuracy: 0.7233 - val_loss: 0.7539 - val_accuracy: 0.7442 - 21s/epoch - 17ms/step
# Epoch 52/100
#
# Epoch 00052: val_loss did not improve from 0.72279
# 1250/1250 - 21s - loss: 0.8074 - accuracy: 0.7250 - val_loss: 0.7694 - val_accuracy: 0.7382 - 21s/epoch - 17ms/step
# Epoch 53/100
#
# Epoch 00053: val_loss improved from 0.72279 to 0.68889, saving model to best-cifar10-v2.h5
# 1250/1250 - 21s - loss: 0.8076 - accuracy: 0.7263 - val_loss: 0.6889 - val_accuracy: 0.7636 - 21s/epoch - 16ms/step
# Epoch 54/100
#
# Epoch 00054: val_loss did not improve from 0.68889
# 1250/1250 - 21s - loss: 0.8053 - accuracy: 0.7259 - val_loss: 0.7641 - val_accuracy: 0.7432 - 21s/epoch - 17ms/step
# Epoch 55/100
#
# Epoch 00055: val_loss did not improve from 0.68889
# 1250/1250 - 21s - loss: 0.8021 - accuracy: 0.7290 - val_loss: 0.7480 - val_accuracy: 0.7522 - 21s/epoch - 17ms/step
# Epoch 56/100
#
# Epoch 00056: val_loss did not improve from 0.68889
# 1250/1250 - 21s - loss: 0.8022 - accuracy: 0.7258 - val_loss: 0.6962 - val_accuracy: 0.7629 - 21s/epoch - 17ms/step
# Epoch 57/100
#
# Epoch 00057: val_loss improved from 0.68889 to 0.66420, saving model to best-cifar10-v2.h5
# 1250/1250 - 21s - loss: 0.7988 - accuracy: 0.7291 - val_loss: 0.6642 - val_accuracy: 0.7712 - 21s/epoch - 17ms/step
# Epoch 58/100
#
# Epoch 00058: val_loss did not improve from 0.66420
# 1250/1250 - 20s - loss: 0.8045 - accuracy: 0.7264 - val_loss: 0.7322 - val_accuracy: 0.7516 - 20s/epoch - 16ms/step
# Epoch 59/100
#
# Epoch 00059: val_loss did not improve from 0.66420
# 1250/1250 - 21s - loss: 0.8004 - accuracy: 0.7240 - val_loss: 0.6765 - val_accuracy: 0.7692 - 21s/epoch - 17ms/step
# Epoch 60/100
#
# Epoch 00060: val_loss did not improve from 0.66420
# 1250/1250 - 21s - loss: 0.8011 - accuracy: 0.7296 - val_loss: 0.7074 - val_accuracy: 0.7577 - 21s/epoch - 17ms/step
# Epoch 61/100
#
# Epoch 00061: val_loss did not improve from 0.66420
# 1250/1250 - 21s - loss: 0.7945 - accuracy: 0.7308 - val_loss: 0.7241 - val_accuracy: 0.7509 - 21s/epoch - 17ms/step
# Epoch 62/100
#
# Epoch 00062: val_loss did not improve from 0.66420
# 1250/1250 - 21s - loss: 0.7953 - accuracy: 0.7291 - val_loss: 0.7241 - val_accuracy: 0.7548 - 21s/epoch - 16ms/step
# Epoch 63/100
#
# Epoch 00063: val_loss did not improve from 0.66420
# 1250/1250 - 21s - loss: 0.7931 - accuracy: 0.7298 - val_loss: 0.7380 - val_accuracy: 0.7521 - 21s/epoch - 16ms/step
# Epoch 64/100
#
# Epoch 00064: val_loss did not improve from 0.66420
# 1250/1250 - 20s - loss: 0.7911 - accuracy: 0.7294 - val_loss: 0.7653 - val_accuracy: 0.7424 - 20s/epoch - 16ms/step
# Epoch 65/100
#
# Epoch 00065: val_loss did not improve from 0.66420
# 1250/1250 - 21s - loss: 0.7856 - accuracy: 0.7322 - val_loss: 0.6684 - val_accuracy: 0.7737 - 21s/epoch - 17ms/step
# Epoch 66/100
#
# Epoch 00066: val_loss did not improve from 0.66420
# 1250/1250 - 21s - loss: 0.7874 - accuracy: 0.7303 - val_loss: 0.7042 - val_accuracy: 0.7610 - 21s/epoch - 17ms/step
# Epoch 67/100
#
# Epoch 00067: val_loss did not improve from 0.66420
# 1250/1250 - 21s - loss: 0.7892 - accuracy: 0.7320 - val_loss: 0.7182 - val_accuracy: 0.7499 - 21s/epoch - 16ms/step

# %%
best_model = load_model(model_path)
best_model.evaluate(X_test, Y_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.6816 - accuracy: 0.7709
# [0.6816017627716064, 0.7709000110626221]

# %% [markdown]
# - 학습 과정 시각화

# %%
y_acc = hist.history['accuracy']
y_vloss = hist.history['val_loss']
xs = np.arange(1, len(y_acc)+1)

# %%
plt.figure(figsize=(12,8))
plt.plot(xs, y_acc, 'o-', ms=3, label='train accuracy')
plt.plot(xs, y_vloss, 'o-', ms=3, label='validation loss')
plt.legend()
plt.grid()
plt.xlabel('Epoch')
plt.show()
